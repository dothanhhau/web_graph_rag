# %%
from langchain.prompts import ChatPromptTemplate

# Prompt cho tác vụ nhận diện thực thể, quan hệ và thuộc tính
prompt_vietnam = (
	"# Hướng dẫn xây dựng Đồ thị Tri thức từ văn bản quy chế tiếng Việt\n"
	"## 1. Mục tiêu\n"
	"Bạn là một mô hình trích xuất thông tin chất lượng cao, được thiết kế để xây dựng đồ thị tri thức từ văn bản quy định, đặc biệt là quy chế đào tạo đại học bằng tiếng Việt.\n"
	"Hãy cố gắng trích xuất tối đa thông tin có trong văn bản **mà không thêm bất kỳ thông tin nào không được nêu rõ**.\n"
	"- **Node** là các thực thể hoặc khái niệm xuất hiện trong văn bản.\n"
	"- **Edge** là quan hệ giữa các node, phản ánh mối liên kết có trong nội dung văn bản.\n"
	"- Kết quả phải dễ hiểu, rõ ràng, có thể dùng để xây dựng hệ thống truy vấn đồ thị tri thức.\n\n"

	"## 2. Gán nhãn thực thể (Labeling Nodes)\n"
	"- Mỗi node phải có `id` là tên thực thể trích từ văn bản, và `type` là loại thực thể.\n"
	"- Nếu thực thể thuộc các loại thường gặp như: `CHƯƠNG`, `ĐIỀU`, `KHOẢN`, `CHỦ_THỂ`, `HOẠT_ĐỘNG`, `YÊU_CẦU`, `CÓ`, `LÀ`, `HỌC_LỰC`, `KHÁI_NIỆM`, ... thì hãy dùng đúng loại đó.\n"
	"- Nếu thực thể không thuộc các loại trên, HÃY TỰ ĐẶT `type` mới phù hợp bằng tiếng Việt.\n"
	"- Không được dùng số làm `id`. `id` phải là tên nguyên văn hoặc dễ hiểu từ văn bản, ví dụ: \"Chương trình đào tạo\", \"Sinh viên\".\n"
	"- Nếu trong văn bản có mô tả hoặc đặc điểm đi kèm thực thể, hãy trích xuất dưới dạng `properties`.\n"
	"- Mỗi node có thể có thêm các thuộc tính khác như `tiêu_đề`, `tên`, `định_nghĩa`, `mô_tả`, `vai_trò`, `phạm_vi`, v.v.\n"
	"- Nếu thuộc tính không nằm trong danh sách gợi ý, bạn được phép tự đặt tên phù hợp (vẫn theo chuẩn viết thường bằng tiếng Việt có dấu gạch dưới).\n\n"

	"## 3. Gán nhãn quan hệ (Relationships)\n"
	"- Các `edges` phải mô tả chính xác mối liên hệ giữa thực thể nguồn (`source`) và thực thể đích (`target`).\n"
	"- `type` của edge phải là một quan hệ rõ ràng, ngắn gọn, bằng **tiếng Việt viết HOA có dấu gạch dưới**, ví dụ: `QUY_ĐỊNH`, `BAO_GỒM`, `PHẢI_HOÀN_THÀNH`, `LIÊN_QUAN_ĐẾN`, `XẾP_LOẠI`, `THỜI_GIAN`, `LÀM`, `THUỘC`, `THAM_CHIẾU`.\n"
	"- Không dùng tên quan hệ quá cụ thể theo ngữ cảnh tạm thời, ví dụ: `BỊ_CẢNH_BÁO_2_LẦN` là không hợp lệ. Hãy dùng chung như `BỊ_CẢNH_BÁO`.\n"
	"- Nếu quan hệ không nằm trong danh sách gợi ý, bạn được phép tự đặt tên phù hợp (vẫn theo chuẩn viết HOA bằng tiếng Việt có dấu gạch dưới).\n"
	"- Nếu có thông tin bổ sung về quan hệ (ví dụ: điều_kiện, quy_định_chi_tiết, v.v.), hãy thêm vào `properties` của quan hệ.\n"
	"- Nếu thuộc tính không nằm trong danh sách gợi ý, bạn được phép tự đặt tên phù hợp (vẫn theo chuẩn viết thường bằng tiếng Việt có dấu gạch dưới).\n\n"

	"## 4. Đồng nhất thực thể (Coreference Resolution)\n"
	"- Nếu một thực thể xuất hiện nhiều lần với cách gọi khác nhau (VD: \"Trường\", \"Nhà Trường\", \"Trường Đại học Quy Nhơn\", \"trường\"), hãy dùng tên đầy đủ nhất làm ID duy nhất.\n"
	"- Không tạo trùng node cho cùng một thực thể.\n\n"

	"## 5. Tuân thủ định dạng và chính xác\n"
	"- Không giải thích, không thêm bình luận.\n"
	"- Chỉ trả về kết quả theo định dạng JSON gồm `nodes` và `edges`.\n"
	"- Kết quả phải đầy đủ, rõ ràng và có thể phân tích được bằng máy.\n"
)

new_prompt = ChatPromptTemplate.from_messages(
	[
		(
			"system",
			prompt_vietnam,
		),
		(
			"human",
			(
				"Tip: Make sure to answer in the correct format and do "
				"not include any explanations. "
				"Use the given format to extract information from the "
				"following input: {input}"
			),
		),
	]
)

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.documents import Document
from langchain_experimental.graph_transformers import LLMGraphTransformer
load_dotenv()

# Mô hình gpt-4o
os.environ["OPENAI_API_KEY"] = str(os.getenv("OPENAI_API_KEY")) # API OPENAI
llm = ChatOpenAI(temperature=0, model="gpt-4o")

# %%
llm_transformer = LLMGraphTransformer(llm=llm, prompt=new_prompt, node_properties=True ,relationship_properties=True)
# llm_transformer = LLMGraphTransformer(llm=llm, node_properties=True ,relationship_properties=True)

# %%
arr = ['''Tên quy định: Quy định chuẩn đầu ra tin học đối với sinh viên đại học hệ chính quy
Điều 1. Phạm vi và đối tượng áp dụng
1. Văn bản này quy định Chuẩn đầu ra tin học đối với sinh viên đại học hệ chính quy Trường Đại học Quy Nhơn
2. Quy định này áp dụng từ khóa tuyển sinh năm 2015 (khóa 38) trở đi.
3. Quy định này không áp dụng đối với sinh viên ngành Sư phạm Tin học, Công nghệ thông tin.
Điều 2. Chuẩn đầu ra tin học
1. Chuẩn đầu ra tin học được xác định theo Chuẩn kỹ năng sử dụng công nghệ thông tin quy định tại Thông tư số 03/2014/TT-BTTTT ngày 11/03/2014 của Bộ Thông tin và Truyền thông.
2. Chuẩn đầu ra tin học là điều kiện để xét công nhận tốt nghiệp.
3. Trước khi xét tốt nghiệp, sinh viên phải đạt một trong các chứng chỉ sau đây:
a) Chứng chỉ ứng dụng công nghệ thông tin cơ bản do Trường Đại học Quy Nhơn cấp.
b) Chứng chỉ tin học quốc tế IC3 (Internet and Computing Core Certification).
c) Chứng chỉ tin học quốc tế ICDL (International Computer Driving Licence) - đạt ít nhất 6 mô đun sau: ICDL.01, ICDL.02, ICDL.03, ICDL.04, ICDL.05, ICDL.08.
d) Chứng chỉ tin học quốc tế MOS (Microsoft Office Specialist) - đạt 3 chứng chỉ Word/Excel/PowerPoint.
4. Các trường hợp đặc biệt do Hiệu trưởng quyết định.
Điều 3. Tổ chức thực hiện
1. Các ông (bà) Trưởng phòng Khảo thí và Đảm bảo chất lượng, Đào tạo đại học, Công tác sinh viên và các Trưởng đơn vị có liên quan chịu trách nhiệm triển khai và hướng dẫn thực hiện Quy định này.
2. Trung tâm tin học Trường Đại học Quy Nhơn phối hợp với các đơn vị liên quan tổ chức thi và cấp chứng chỉ Chuẩn đầu ra tin học cho sinh viên.
Trong quá trình thực hiện, nếu có vấn đề chưa phù hợp, các đơn vị đề xuất với Nhà trường (qua Phòng Khảo thí và Đảm bảo chất lượng) để bổ sung, điều chỉnh.''']

# %%
# Đọc hết tất cả 14 file để chuẩn bị chuyển thành đồ thị
base_dir = os.getcwd()

# Tạo đường dẫn đến thư mục txt
folder_path = os.path.join(base_dir, 'app', 'static', 'txt')
folder_path = 'D:/WorkSpace/python/thesis/web_graph_rag/app/static/txt'
for filename in os.listdir(folder_path):
	if filename.endswith('.txt'):
		file_path = os.path.join(folder_path, filename)
		with open(file_path, 'r', encoding='utf-8') as f:
			content = f.read()
			arr = arr + content.split('\n\n')
			# print(f"Nội dung của {filename}:\n{content}\n")

# print(len(arr))

# %%
# Đọc 1 file
base_dir = os.getcwd()
# Quy chế đào tạo trình độ đại học.txt
# Quy định về học phí của sinh viên đại học hệ chính quy.txt
# dữ liệu đánh giá.txt
arr = []
file_name = 'miss.txt'
# folder_path = os.path.join(base_dir, 'app', 'static', 'txt', file_name)
folder_path = os.path.join(base_dir, file_name)
with open(folder_path, 'r', encoding='utf-8') as f:
	content = f.read()
	arr = arr + content.split('\n\n')
	# arr.append(content)
	
len(arr)
# Out:
# 5

# %%
# Tạo cấu trúc Document để vào LLMGraphTransformer xử lý
documents = []
for x in arr:
	documents.append(Document(page_content=x))

# %%
# Chuyển các document thành các thực thể và quan hệ
graph_documents = llm_transformer.convert_to_graph_documents(documents=documents)

# %%
# Hiển thị các thực thể và quan hệ
for x in graph_documents:
	print(f"Nodes:{x.nodes}")
	print(f"Relationships:{x.relationships}")
	print()
# Out:
# Nodes:[Node(id='Ngành Sư Phạm Tiếng Anh', type='Ngành', properties={}), Node(id='Ngành Ngôn Ngữ Anh', type='Ngành', properties={}), Node(id='Ngành Ngôn Ngữ Trung Quốc', type='Ngành', properties={}), Node(id='Ngành Chất Lượng Cao', type='Ngành', properties={}), Node(id='Các Ngành Khác', type='Ngành', properties={}), Node(id='Trường Đại Học Quy Nhơn', type='Tổ_chức', properties={}), Node(id='Bộ Giáo Dục Và Đào Tạo', type='Tổ_chức', properties={}), Node(id='Ngoại Ngữ 1', type='Khái_niệm', properties={}), Node(id='Ngoại Ngữ 2', type='Khái_niệm', properties={}), Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), Node(id='Tiếng Pháp Bậc 3/6', type='Yêu_cầu', properties={}), Node(id='Tiếng Trung Bậc 3/6', type='Yêu_cầu', properties={}), Node(id='Tiếng Anh Bậc 3/6', type='Yêu_cầu', properties={}), Node(id='Tiếng Pháp Bậc 4/6', type='Yêu_cầu', properties={}), Node(id='Tiếng Anh Bậc 4/6', type='Yêu_cầu', properties={}), Node(id='Cefr C1', type='Chứng_chỉ', properties={}), Node(id='Cae 60', type='Chứng_chỉ', properties={}), Node(id='Ielts 6.5', type='Chứng_chỉ', properties={}), Node(id='Toefl Ibt 85', type='Chứng_chỉ', properties={}), Node(id='Toeic 850', type='Chứng_chỉ', properties={}), Node(id='Aptis Esol General C', type='Chứng_chỉ', properties={}), Node(id='Aptis Esol Advanced C1', type='Chứng_chỉ', properties={}), Node(id='Jlpt N4', type='Chứng_chỉ', properties={}), Node(id='Jtest E', type='Chứng_chỉ', properties={}), Node(id='Hsk 3', type='Chứng_chỉ', properties={}), Node(id='Delf B1', type='Chứng_chỉ', properties={}), Node(id='Tcf Niveau 3', type='Chứng_chỉ', properties={}), Node(id='Topik 3', type='Chứng_chỉ', properties={}), Node(id='Cefr B1', type='Chứng_chỉ', properties={}), Node(id='Ielts 4.5', type='Chứng_chỉ', properties={}), Node(id='Toefl Ibt 45', type='Chứng_chỉ', properties={}), Node(id='Toeic 450', type='Chứng_chỉ', properties={}), Node(id='Aptis Esol General B1', type='Chứng_chỉ', properties={}), Node(id='Aptis Esol Advanced B1', type='Chứng_chỉ', properties={}), Node(id='Linguaskill B1', type='Chứng_chỉ', properties={}), Node(id='Cefr B2', type='Chứng_chỉ', properties={}), Node(id='Ielts 5.5', type='Chứng_chỉ', properties={}), Node(id='Toefl Ibt 61', type='Chứng_chỉ', properties={}), Node(id='Toeic 600', type='Chứng_chỉ', properties={}), Node(id='Aptis Esol General B2', type='Chứng_chỉ', properties={}), Node(id='Aptis Esol Advanced B2', type='Chứng_chỉ', properties={}), Node(id='Linguaskill B2', type='Chứng_chỉ', properties={}), Node(id='Jlpt N3', type='Chứng_chỉ', properties={}), Node(id='Jtest D', type='Chứng_chỉ', properties={}), Node(id='Hsk 4', type='Chứng_chỉ', properties={}), Node(id='Delf B2', type='Chứng_chỉ', properties={}), Node(id='Tcf Niveau 4', type='Chứng_chỉ', properties={}), Node(id='Topik 4', type='Chứng_chỉ', properties={})]
# Relationships:[Relationship(source=Node(id='Ngành Sư Phạm Tiếng Anh', type='Ngành', properties={}), target=Node(id='Ngoại Ngữ 1', type='Khái_niệm', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Ngành Sư Phạm Tiếng Anh', type='Ngành', properties={}), target=Node(id='Ngoại Ngữ 2', type='Khái_niệm', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Ngoại Ngữ 1', type='Khái_niệm', properties={}), target=Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), type='ĐẠT', properties={}), Relationship(source=Node(id='Ngoại Ngữ 2', type='Khái_niệm', properties={}), target=Node(id='Tiếng Pháp Bậc 3/6', type='Yêu_cầu', properties={}), type='ĐẠT', properties={}), Relationship(source=Node(id='Ngoại Ngữ 2', type='Khái_niệm', properties={}), target=Node(id='Tiếng Trung Bậc 3/6', type='Yêu_cầu', properties={}), type='ĐẠT', properties={}), Relationship(source=Node(id='Ngành Ngôn Ngữ Anh', type='Ngành', properties={}), target=Node(id='Tiếng Pháp Bậc 3/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Ngành Ngôn Ngữ Anh', type='Ngành', properties={}), target=Node(id='Tiếng Trung Bậc 3/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Ngành Ngôn Ngữ Trung Quốc', type='Ngành', properties={}), target=Node(id='Tiếng Anh Bậc 3/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Ngành Ngôn Ngữ Trung Quốc', type='Ngành', properties={}), target=Node(id='Tiếng Pháp Bậc 3/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Ngành Chất Lượng Cao', type='Ngành', properties={}), target=Node(id='Tiếng Anh Bậc 4/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Ngành Chất Lượng Cao', type='Ngành', properties={}), target=Node(id='Tiếng Pháp Bậc 4/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Các Ngành Khác', type='Ngành', properties={}), target=Node(id='Tiếng Anh Bậc 3/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Các Ngành Khác', type='Ngành', properties={}), target=Node(id='Tiếng Pháp Bậc 3/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Các Ngành Khác', type='Ngành', properties={}), target=Node(id='Tiếng Trung Bậc 3/6', type='Yêu_cầu', properties={}), type='YÊU_CẦU', properties={}), Relationship(source=Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), target=Node(id='Cefr C1', type='Chứng_chỉ', properties={}), type='TƯƠNG_ĐƯƠNG', properties={}), Relationship(source=Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), target=Node(id='Cae 60', type='Chứng_chỉ', properties={}), type='TƯƠNG_ĐƯƠNG', properties={}), Relationship(source=Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), target=Node(id='Ielts 6.5', type='Chứng_chỉ', properties={}), type='TƯƠNG_ĐƯƠNG', properties={}), Relationship(source=Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), target=Node(id='Toefl Ibt 85', type='Chứng_chỉ', properties={}), type='TƯƠNG_ĐƯƠNG', properties={}), Relationship(source=Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), target=Node(id='Toeic 850', type='Chứng_chỉ', properties={}), type='TƯƠNG_ĐƯƠNG', properties={}), Relationship(source=Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), target=Node(id='Aptis Esol General C', type='Chứng_chỉ', properties={}), type='TƯƠNG_ĐƯƠNG', properties={}), Relationship(source=Node(id='Tiếng Anh Bậc 5/6', type='Yêu_cầu', properties={}), target=Node(id='Aptis Esol Advanced C1', type='Chứng_chỉ', properties={}), type='TƯƠNG_ĐƯƠNG', properties={}), Relationship(source=Node(id='Tiếng Pháp Bậc 3/6', type='Yêu_cầu', properties={}), target=Node(id='Delf B1', type='Chứng_chỉ', properties={}), type='TƯƠNG_ĐƯƠNG', properties={}), Relationship(s ...

# %%
# Một các hiển thị dễ quan sát hơn
for x in graph_documents:
	for y in x.nodes:
		print(f"{y.type} - {y.id} - {y.properties}")
	print()
	for y in x.relationships:
		print(f"({y.source.type}: {y.source.id}) - ({y.type}:{y.properties}) - ({y.target.type}:{y.target.id})")
	
	print('-'*40)
	print()
# Out:
# Ngành - Ngành Sư Phạm Tiếng Anh (Ngoại Ngữ 1) - {}
# Ngành - Ngành Sư Phạm Tiếng Anh (Ngoại Ngữ 2) - {}
# Ngành - Ngành Ngôn Ngữ Anh - {}
# Ngành - Ngành Ngôn Ngữ Trung Quốc - {}
# Ngành - Các Ngành Chất Lượng Cao - {}
# Ngành - Các Ngành Khác - {}
# Tổ_chức - Trường Đại Học Quy Nhơn - {}
# Tổ_chức - Bộ Giáo Dục Và Đào Tạo - {}
# Chứng_nhận - Chứng Nhận Tiếng Anh Bậc 5/6 - {}
# Chứng_nhận - Chứng Nhận Tiếng Pháp Bậc 3/6 - {}
# Chứng_nhận - Chứng Nhận Tiếng Trung Bậc 3/6 - {}
# Chứng_nhận - Chứng Nhận Tiếng Anh Bậc 3/6 - {}
# Chứng_nhận - Chứng Nhận Tiếng Pháp Bậc 4/6 - {}
# Chứng_nhận - Chứng Nhận Tiếng Trung Bậc 4/6 - {}
# Chứng_chỉ - Chứng Chỉ Quốc Tế - {'danh_sách': 'CEFR C1, CAE 60, IELTS 6.5, TOEFL iBT 85, TOEIC 850, APTIS ESOL GENERAL C, APTIS ESOL ADVANCED C1'}
# Chứng_chỉ - Chứng Chỉ Quốc Tế - {'danh_sách': 'JLPT N4, JTEST Cấp độ E, HSK Cấp độ 3, DELF B1, TCF Niveau 3, TOPIK 3'}
# Chứng_chỉ - Chứng Chỉ Quốc Tế - {'danh_sách': 'CEFR B1, IELTS 4.5, TOEFL iBT 45, TOEIC 450, APTIS ESOL GENERAL B1, APTIS ESOL ADVANCED B1, LINGUASKILL B1, JLPT N4, JTEST Cấp độ E, DELF B1, TCF Niveau 3, TOPIK 3'}
# Chứng_chỉ - Chứng Chỉ Quốc Tế - {'danh_sách': 'CEFR B2, IELTS 5.5, TOEFL iBT 61, TOEIC 600, APTIS ESOL GENERAL B2, APTIS ESOL ADVANCED B2, LINGUASKILL B2, JLPT N3, JTEST Cấp độ D, HSK Cấp độ 4, DELF B2, TCF Niveau 4, TOPIK 4'}
#
# (Ngành: Ngành Sư Phạm Tiếng Anh (Ngoại Ngữ 1)) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Anh Bậc 5/6)
# (Ngành: Ngành Sư Phạm Tiếng Anh (Ngoại Ngữ 1)) - (CHẤP_NHẬN:{'danh_sách': 'CEFR C1, CAE 60, IELTS 6.5, TOEFL iBT 85, TOEIC 850, APTIS ESOL GENERAL C, APTIS ESOL ADVANCED C1'}) - (Chứng_chỉ:Chứng Chỉ Quốc Tế)
# (Ngành: Ngành Sư Phạm Tiếng Anh (Ngoại Ngữ 2)) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Pháp Bậc 3/6)
# (Ngành: Ngành Sư Phạm Tiếng Anh (Ngoại Ngữ 2)) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Trung Bậc 3/6)
# (Ngành: Ngành Sư Phạm Tiếng Anh (Ngoại Ngữ 2)) - (CHẤP_NHẬN:{'danh_sách': 'JLPT N4, JTEST Cấp độ E, HSK Cấp độ 3, DELF B1, TCF Niveau 3, TOPIK 3'}) - (Chứng_chỉ:Chứng Chỉ Quốc Tế)
# (Ngành: Ngành Ngôn Ngữ Anh) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Pháp Bậc 3/6)
# (Ngành: Ngành Ngôn Ngữ Anh) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Trung Bậc 3/6)
# (Ngành: Ngành Ngôn Ngữ Anh) - (CHẤP_NHẬN:{'danh_sách': 'JLPT N4, JTEST Cấp độ E, HSK Cấp độ 3, DELF B1, TCF Niveau 3, TOPIK 3'}) - (Chứng_chỉ:Chứng Chỉ Quốc Tế)
# (Ngành: Ngành Ngôn Ngữ Trung Quốc) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Anh Bậc 3/6)
# (Ngành: Ngành Ngôn Ngữ Trung Quốc) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Pháp Bậc 3/6)
# (Ngành: Ngành Ngôn Ngữ Trung Quốc) - (CHẤP_NHẬN:{'danh_sách': 'CEFR B1, IELTS 4.5, TOEFL iBT 45, TOEIC 450, APTIS ESOL GENERAL B1, APTIS ESOL ADVANCED B1, LINGUASKILL B1, JLPT N4, JTEST Cấp độ E, DELF B1, TCF Niveau 3, TOPIK 3'}) - (Chứng_chỉ:Chứng Chỉ Quốc Tế)
# (Ngành: Các Ngành Chất Lượng Cao) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Anh Bậc 4/6)
# (Ngành: Các Ngành Chất Lượng Cao) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Pháp Bậc 4/6)
# (Ngành: Các Ngành Chất Lượng Cao) - (CHẤP_NHẬN:{'danh_sách': 'CEFR B2, IELTS 5.5, TOEFL iBT 61, TOEIC 600, APTIS ESOL GENERAL B2, APTIS ESOL ADVANCED B2, LINGUASKILL B2, JLPT N3, JTEST Cấp độ D, HSK Cấp độ 4, DELF B2, TCF Niveau 4, TOPIK 4'}) - (Chứng_chỉ:Chứng Chỉ Quốc Tế)
# (Ngành: Các Ngành Khác) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Anh Bậc 3/6)
# (Ngành: Các Ngành Khác) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Pháp Bậc 3/6)
# (Ngành: Các Ngành Khác) - (YÊU_CẦU:{}) - (Chứng_nhận:Chứng Nhận Tiếng Trung Bậc 3/6)
# (Ngành: Các Ngành Khác) - (CHẤP_NHẬN:{'danh_sách': 'CEFR B1, IELTS 4.5, TOEFL iBT 45, TOEIC 450, APTIS ESOL GENERAL B1, APTIS ESOL ADVANCED B1, LINGUASKILL B1, JLPT N4, JTEST Cấp độ E, HSK Cấp độ 3, DELF B1, TCF Niveau 3, TOPIK 3'}) - (Chứng_chỉ:Chứng Chỉ Quốc Tế)
# ----------------------------------------
#
# Chủ_thể - Sv Nội Trú - {}
# Hoạt_động - Cải Tạo Phòng - {}
# Hoạt_động - Thay Đổi Hoặc Tự Ý Di Chuyển Trang Thiết Bị - {}
# Hoạt_động - Gây Mất Trật Tự, An Ninh, Vệ Sinh Môi Trường - {}
# Hoạt_động - Viết Vẽ, Che Chắn Làm Mất Mỹ Quan - {}
# Hoạt_động - Chuyển Nhượng Hoặc Cho Thuê Lại Hợp Đồng - {}
# Hoạt_động - Tự Ý Đưa Người Lạ Vào Phòng - {}
# Hoạt_động - Trộm Cắp Tài Sản - {}
# Hoạt_động - Sản Xuất, Tàng Trữ, Sử Dụng, Buôn Bán, Vận Chuyển, Phát Tán Các Loại Vũ Khí, Chất Gây Cháy, Gây Nổ, Hóa Chất Độc Hại, Ma Túy Và Các Chế Phẩm Của Ma Túy - {}
# Hoạt_động - Phát Tán Các Tài Liệu, Ấn Phẩm, Phim Ảnh, Thông Tin Phản Động, Đồi Trụy Và Các Tài Liệu Cấm Khác - {}
# Hoạt_động - Tổ Chức Hoặc Tham Gia Đánh Bạc, Mại Dâm - {}
# Hoạt_động - Truyền Bá Các Hoạt Động Mê Tín Dị Đoan, Các Hoạt Động Tôn Giáo - {}
# Hoạt_động - Tổ Chức Băng, Nhóm Và Đánh Nhau - {}
#
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Cải Tạo Phòng)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Thay Đổi Hoặc Tự Ý Di Chuyển Trang Thiết Bị)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Gây Mất Trật Tự, An Ninh, Vệ Sinh Môi Trường)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Viết Vẽ, Che Chắn Làm Mất Mỹ Quan)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Chuyển Nhượng Hoặc Cho Thuê Lại Hợp Đồng)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Tự Ý Đưa Người Lạ Vào Phòng)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Trộm Cắp Tài Sản)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Sản Xuất, Tàng Trữ, Sử Dụng, Buôn Bán, Vận Chuyển, Phát Tán Các Loại Vũ Khí, Chất Gây Cháy, Gây Nổ, Hóa Chất Độc Hại, Ma Túy Và Các Chế Phẩm Của Ma Túy)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Phát Tán Các Tài Liệu, Ấn Phẩm, Phim Ảnh, Thông Tin Phản Động, Đồi Trụy Và Các Tài Liệu Cấm Khác)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Tổ Chức Hoặc Tham Gia Đánh Bạc, Mại Dâm)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Truyền Bá Các Hoạt Động Mê Tín Dị Đoan, Các Hoạt Động Tôn Giáo)
# (Chủ_thể: Sv Nội Trú) - (KHÔNG_ĐƯỢC_LÀM:{}) - (Hoạt_động:Tổ Chức Băng, Nhóm Và Đánh Nhau)
# ----------------------------------------
#
# Chủ_thể - Sinh Viên - {}
# Khái_niệm - Ngành, Nghề Đã Đăng Ký Dự Tuyển - {}
# Yêu_cầu - Điều Kiện Trúng Tuyển - {}
# Chủ_thể - Bộ Giáo Dục Và Đào Tạo - {}
# Chủ_thể - Nhà Trường - {}
# Khái_niệm - Thông Tin Cá Nhân - {}
# Khái_niệm - Nội Quy, Quy Chế Về Đào Tạo, Rèn Luyện - {}
# Khái_niệm - Chế Độ, Chính Sách Của Nhà Nước - {}
# Khái_niệm - Hệ Thống Thư Viện - {}
# Khái_niệm - Trang Thiết Bị Và Phương Tiện Phục Vụ Học Tập - {}
# Hoạt_động - Nghiên Cứu Khoa Học - {}
# Hoạt_động - Văn Hóa, Văn Nghệ, Thể Dục, Thể Thao - {}
# Hoạt_động - Thi Sinh Viên Giỏi - {}
# Hoạt_động - Thi Olympic Các Môn Học - {}
# Hoạt_động - Thi Sáng Tạo Khoa Học, Kỹ Thuật - {}
# Hoạt_động - Chăm Sóc, Bảo Vệ Sức Khỏe - {}
# Hoạt_động - Hoạt Động Giao Lưu, Trao Đổi Sinh Viên Ở Nước Ngoài - {}
# Hoạt_động - Học Chuyển Tiếp - {}
# Chủ_thể - Tổ Chức Đảng Cộng Sản Việt Nam - {}
# Chủ_thể - Đoàn Tncs Hồ Chí Minh - {}
# Chủ_thể - Hội Sinh Viên Việt Nam - {}
# Chủ_thể - Tổ Chức Tự Quản Của Sinh Viên - {}
# Hoạt_động - Hoạt Động Xã Hội - {}
# Khái_niệm - Dịch Vụ Công Tác Xã Hội - {}
# Hoạt_động - Nghỉ Học Tạm Thời, Tạm Ngừng Học - {}
# Hoạt_động - Học Theo Tiến Độ Chậm, Tiến Độ Nhanh - {}
# Hoạt_động - Học Cùng Lúc Hai Chương Trình - {}
# Hoạt_động - Chuyển Trường - {}
# Khái_niệm - Quy Chế Về Đào Tạo Của Bộ Giáo Dục Và Đào Tạo - {}
# Hoạt_động - Nghỉ Hè, Nghỉ Tết, Nghỉ Lễ - {}
# Khái_niệm - Học Bổng Khuyến Khích Học Tập - {}
# Khái_niệm - Học Bổng Do Các Tổ Chức, Cá Nhân Tài Trợ - {}
# Khái_niệm - Miễn Giảm Phí Dịch Vụ Công Cộng - {}
# Hoạt_động - Góp Ý Kiến, Tham Gia Quản Lý Và Giám Sát - {}
# Khái_niệm - Điều Kiện Đảm Bảo Chất Lượng Giáo Dục - {}
# Chủ_thể - Đại Diện Hợp Pháp Của Sinh Viên - {}
# Hoạt_động - Kiến Nghị Giải Pháp - {}
# Khái_niệm - Nguyện Vọng Và Khiếu Nại - {}
# Chủ_thể - Hiệu Trưởng - {}
# Khái_niệm - Ký Túc Xá - {}
# Khái_niệm - Bằng Tốt Nghiệp, Chứng Chỉ, Bảng Điểm - {}
# Khái_niệm - Giấy Tờ Liên Quan Và Thủ Tục Hành Chính - {}
#
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_NHẬN_VÀO:{}) - (Khái_niệm:Ngành, Nghề Đã Đăng Ký Dự Tuyển)
# (Khái_niệm: Ngành, Nghề Đã Đăng Ký Dự Tuyển) - (CÓ:{}) - (Yêu_cầu:Điều Kiện Trúng Tuyển)
# (Yêu_cầu: Điều Kiện Trúng Tuyển) - (QUY_ĐỊNH:{}) - (Chủ_thể:Bộ Giáo Dục Và Đào Tạo)
# (Yêu_cầu: Điều Kiện Trúng Tuyển) - (QUY_ĐỊNH:{}) - (Chủ_thể:Nhà Trường)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_CUNG_CẤP:{}) - (Khái_niệm:Thông Tin Cá Nhân)
# (Khái_niệm: Thông Tin Cá Nhân) - (QUY_ĐỊNH:{}) - (Chủ_thể:Nhà Trường)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_PHỔ_BIẾN:{}) - (Khái_niệm:Nội Quy, Quy Chế Về Đào Tạo, Rèn Luyện)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_PHỔ_BIẾN:{}) - (Khái_niệm:Chế Độ, Chính Sách Của Nhà Nước)
# (Chủ_thể: Sinh Viên) - (SỬ_DỤNG:{}) - (Khái_niệm:Hệ Thống Thư Viện)
# (Chủ_thể: Sinh Viên) - (SỬ_DỤNG:{}) - (Khái_niệm:Trang Thiết Bị Và Phương Tiện Phục Vụ Học Tập)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Hoạt_động:Nghiên Cứu Khoa Học)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Hoạt_động:Văn Hóa, Văn Nghệ, Thể Dục, Thể Thao)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Hoạt_động:Thi Sinh Viên Giỏi)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Hoạt_động:Thi Olympic Các Môn Học)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Hoạt_động:Thi Sáng Tạo Khoa Học, Kỹ Thuật)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_HƯỞNG:{}) - (Hoạt_động:Chăm Sóc, Bảo Vệ Sức Khỏe)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Hoạt_động:Hoạt Động Giao Lưu, Trao Đổi Sinh Viên Ở Nước Ngoài)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Hoạt_động:Học Chuyển Tiếp)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Chủ_thể:Tổ Chức Đảng Cộng Sản Việt Nam)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Chủ_thể:Đoàn Tncs Hồ Chí Minh)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Chủ_thể:Hội Sinh Viên Việt Nam)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Chủ_thể:Tổ Chức Tự Quản Của Sinh Viên)
# (Chủ_thể: Sinh Viên) - (THAM_GIA:{}) - (Hoạt_động:Hoạt Động Xã Hội)
# (Chủ_thể: Sinh Viên) - (SỬ_DỤNG:{}) - (Khái_niệm:Dịch Vụ Công Tác Xã Hội)
# (Chủ_thể: Sinh Viên) - (THỰC_HIỆN:{}) - (Hoạt_động:Nghỉ Học Tạm Thời, Tạm Ngừng Học)
# (Chủ_thể: Sinh Viên) - (THỰC_HIỆN:{}) - (Hoạt_động:Học Theo Tiến Độ Chậm, Tiến Độ Nhanh)
# (Chủ_thể: Sinh Viên) - (THỰC_HIỆN:{}) - (Hoạt_động:Học Cùng Lúc Hai Chương Trình)
# (Chủ_thể: Sinh Viên) - (THỰC_HIỆN:{}) - (Hoạt_động:Chuyển Trường)
# (Hoạt_động: Chuyển Trường) - (THEO:{}) - (Khái_niệm:Quy Chế Về Đào Tạo Của Bộ Giáo Dục Và Đào Tạo)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_HƯỞNG:{}) - (Hoạt_động:Nghỉ Hè, Nghỉ Tết, Nghỉ Lễ)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_XÉT_NHẬN:{}) - (Khái_niệm:Học Bổng Khuyến Khích Học Tập)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_XÉT_NHẬN:{}) - (Khái_niệm:Học Bổng Do Các Tổ Chức, Cá Nhân Tài Trợ)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_HƯỞNG:{}) - (Khái_niệm:Miễn Giảm Phí Dịch Vụ Công Cộng)
# (Chủ_thể: Sinh Viên) - (THỰC_HIỆN:{}) - (Hoạt_động:Góp Ý Kiến, Tham Gia Quản Lý Và Giám Sát)
# (Hoạt_động: Góp Ý Kiến, Tham Gia Quản Lý Và Giám Sát) - (LIÊN_QUAN_ĐẾN:{}) - (Khái_niệm:Điều Kiện Đảm Bảo Chất Lượng Giáo Dục)
# (Chủ_thể: Sinh Viên) - (THỰC_HIỆN:{}) - (Hoạt_động:Kiến Nghị Giải Pháp)
# (Chủ_thể: Sinh Viên) - (ĐỀ_ĐẠT:{}) - (Khái_niệm:Nguyện Vọng Và Khiếu Nại)
# (Khái_niệm: Nguyện Vọng Và Khiếu Nại) - (GIẢI_QUYẾT:{}) - (Chủ_thể:Hiệu Trưởng)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_XÉT_TIẾP_NHẬN:{}) - (Khái_niệm:Ký Túc Xá)
# (Chủ_thể: Sinh Viên) - (ĐƯỢC_CẤP:{}) - (Khái_niệm:Bằng Tốt Nghiệp, Chứng Chỉ, Bảng Điểm)
# (Chủ_thể: Sinh Viên) - (GIẢI_QUYẾT:{}) - (Khái_niệm:Giấy Tờ Liên Quan Và Thủ Tục Hành Chính)
# ----------------------------------------
#
# Điều - Điều 15 - {'tiêu_đề': 'Công tác quản lý sinh viên'}
# Hoạt_động - Công Tác Hành Chính - {}
# Hoạt_động - Công Tác Khen Thưởng Và Kỷ Luật - {}
# Hoạt_động - Công Tác Sinh Viên Nội Trú, Ngoại Trú - {}
# Hoạt_động - Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học - {}
# Hoạt_động - Thực Hiện Các Chế Độ, Chính Sách Đối Với Sinh Viên - {}
# Chủ_thể - Sinh Viên - {}
# Chủ_thể - Bộ Giáo Dục Và Đào Tạo - {}
# Chủ_thể - Đảng - {}
# Chủ_thể - Nhà Nước - {}
# Chủ_thể - Công An Địa Phương - {}
# Hoạt_động - Tiếp Nhận Thí Sinh Trúng Tuyển - {}
# Hoạt_động - Sắp Xếp, Bố Trí Sinh Viên Vào Các Lớp - {}
# Hoạt_động - Chỉ Định Ban Cán Sự Lớp - {}
# Hoạt_động - Làm Thẻ Sinh Viên, Thẻ Thư Viện - {}
# Hoạt_động - Quản Lý, Tổ Chức Cấp Phát Văn Bằng, Chứng Chỉ - {}
# Hoạt_động - Thống Kê, Tổng Hợp Dữ Liệu - {}
# Hoạt_động - Quản Lý, Lưu Trữ Hồ Sơ - {}
# Hoạt_động - Giải Quyết Các Công Việc Hành Chính - {}
# Hoạt_động - Theo Dõi, Đánh Giá Ý Thức Học Tập - {}
# Hoạt_động - Tổ Chức Đánh Giá Kết Quả Rèn Luyện - {}
# Hoạt_động - Phân Loại, Xếp Loại Sinh Viên - {}
# Hoạt_động - Phát Động, Tổ Chức Các Phong Trào Thi Đua - {}
# Hoạt_động - Tổ Chức Đánh Giá, Bình Bầu Và Khen Thưởng - {}
# Hoạt_động - Tổ Chức Cho Sinh Viên Nghiên Cứu Khoa Học - {}
# Hoạt_động - Thi Olympic Các Môn Học - {}
# Hoạt_động - Thi Sáng Tạo Tài Năng Trẻ - {}
# Hoạt_động - Hướng Dẫn, Kiểm Tra, Giám Sát Việc Thực Hiện Các Quy Chế, Quy Định - {}
# Hoạt_động - Tham Mưu, Theo Dõi Và Tổng Hợp Việc Xử Lý Kỷ Luật - {}
# Hoạt_động - Tổ Chức Thực Hiện Các Nội Dung, Biện Pháp Công Tác Sinh Viên Nội Trú, Ngoại Trú - {}
# Hoạt_động - Ban Hành Nội Quy, Quy Định - {}
# Hoạt_động - Xây Dựng Kế Hoạch, Tổ Chức Kiểm Tra, Giám Sát - {}
# Hoạt_động - Phối Hợp Với Công An Địa Phương - {}
# Hoạt_động - Xây Dựng Môi Trường Giáo Dục Lành Mạnh - {}
# Hoạt_động - Theo Dõi, Nắm Bắt Diễn Biến Tư Tưởng, Hành Vi Của Sinh Viên - {}
# Hoạt_động - Phối Hợp Ngăn Chặn Việc Kích Động, Lôi Kéo Sinh Viên - {}
# Hoạt_động - Phối Hợp Xử Lý Các Vụ Việc Về An Ninh, Trật Tự Trường Học - {}
# Hoạt_động - Tuyên Truyền, Hướng Dẫn, Theo Dõi, Tổng Hợp Và Giải Quyết Các Chế Độ, Chính Sách - {}
#
# (Điều: Điều 15) - (BAO_GỒM:{}) - (Hoạt_động:Công Tác Hành Chính)
# (Điều: Điều 15) - (BAO_GỒM:{}) - (Hoạt_động:Công Tác Khen Thưởng Và Kỷ Luật)
# (Điều: Điều 15) - (BAO_GỒM:{}) - (Hoạt_động:Công Tác Sinh Viên Nội Trú, Ngoại Trú)
# (Điều: Điều 15) - (BAO_GỒM:{}) - (Hoạt_động:Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học)
# (Điều: Điều 15) - (BAO_GỒM:{}) - (Hoạt_động:Thực Hiện Các Chế Độ, Chính Sách Đối Với Sinh Viên)
# (Hoạt_động: Công Tác Hành Chính) - (BAO_GỒM:{}) - (Hoạt_động:Tiếp Nhận Thí Sinh Trúng Tuyển)
# (Hoạt_động: Công Tác Hành Chính) - (BAO_GỒM:{}) - (Hoạt_động:Sắp Xếp, Bố Trí Sinh Viên Vào Các Lớp)
# (Hoạt_động: Công Tác Hành Chính) - (BAO_GỒM:{}) - (Hoạt_động:Chỉ Định Ban Cán Sự Lớp)
# (Hoạt_động: Công Tác Hành Chính) - (BAO_GỒM:{}) - (Hoạt_động:Làm Thẻ Sinh Viên, Thẻ Thư Viện)
# (Hoạt_động: Công Tác Hành Chính) - (BAO_GỒM:{}) - (Hoạt_động:Quản Lý, Tổ Chức Cấp Phát Văn Bằng, Chứng Chỉ)
# (Hoạt_động: Công Tác Hành Chính) - (BAO_GỒM:{}) - (Hoạt_động:Thống Kê, Tổng Hợp Dữ Liệu)
# (Hoạt_động: Công Tác Hành Chính) - (BAO_GỒM:{}) - (Hoạt_động:Quản Lý, Lưu Trữ Hồ Sơ)
# (Hoạt_động: Công Tác Hành Chính) - (BAO_GỒM:{}) - (Hoạt_động:Giải Quyết Các Công Việc Hành Chính)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Theo Dõi, Đánh Giá Ý Thức Học Tập)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Tổ Chức Đánh Giá Kết Quả Rèn Luyện)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{'điều_kiện': 'cuối mỗi học kỳ, năm học, khóa học theo Quy chế của Bộ Giáo dục và Đào tạo'}) - (Hoạt_động:Phân Loại, Xếp Loại Sinh Viên)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Phát Động, Tổ Chức Các Phong Trào Thi Đua)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Tổ Chức Đánh Giá, Bình Bầu Và Khen Thưởng)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Tổ Chức Cho Sinh Viên Nghiên Cứu Khoa Học)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Thi Olympic Các Môn Học)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Thi Sáng Tạo Tài Năng Trẻ)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Hướng Dẫn, Kiểm Tra, Giám Sát Việc Thực Hiện Các Quy Chế, Quy Định)
# (Hoạt_động: Công Tác Khen Thưởng Và Kỷ Luật) - (BAO_GỒM:{}) - (Hoạt_động:Tham Mưu, Theo Dõi Và Tổng Hợp Việc Xử Lý Kỷ Luật)
# (Hoạt_động: Công Tác Sinh Viên Nội Trú, Ngoại Trú) - (BAO_GỒM:{'theo_quy_định': 'của Bộ Giáo dục và Đào tạo'}) - (Hoạt_động:Tổ Chức Thực Hiện Các Nội Dung, Biện Pháp Công Tác Sinh Viên Nội Trú, Ngoại Trú)
# (Hoạt_động: Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học) - (BAO_GỒM:{}) - (Hoạt_động:Ban Hành Nội Quy, Quy Định)
# (Hoạt_động: Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học) - (BAO_GỒM:{'theo_văn_bản': 'của Đảng, Nhà nước'}) - (Hoạt_động:Xây Dựng Kế Hoạch, Tổ Chức Kiểm Tra, Giám Sát)
# (Hoạt_động: Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học) - (BAO_GỒM:{}) - (Hoạt_động:Phối Hợp Với Công An Địa Phương)
# (Hoạt_động: Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học) - (BAO_GỒM:{}) - (Hoạt_động:Xây Dựng Môi Trường Giáo Dục Lành Mạnh)
# (Hoạt_động: Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học) - (BAO_GỒM:{}) - (Hoạt_động:Theo Dõi, Nắm Bắt Diễn Biến Tư Tưởng, Hành Vi Của Sinh Viên)
# (Hoạt_động: Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học) - (BAO_GỒM:{}) - (Hoạt_động:Phối Hợp Ngăn Chặn Việc Kích Động, Lôi Kéo Sinh Viên)
# (Hoạt_động: Công Tác Bảo Đảm An Ninh, Trật Tự Trường Học) - (BAO_GỒM:{}) - (Hoạt_động:Phối Hợp Xử Lý Các Vụ Việc Về An Ninh, Trật Tự Trường Học)
# (Hoạt_động: Thực Hiện Các Chế Độ, Chính Sách Đối Với Sinh Viên) - (BAO_GỒM:{'theo_quy_định': 'của Nhà nước'}) - (Hoạt_động:Tuyên Truyền, Hướng Dẫn, Theo Dõi, Tổng Hợp Và Giải Quyết Các Chế Độ, Chính Sách)
# ----------------------------------------
#
# Vi_phạm - Đến Muộn Giờ Học, Giờ Thực Tập; Nghỉ Học Không Phép Hoặc Quá Phép - {}
# Vi_phạm - Mất Trật Tự, Làm Việc Riêng Trong Giờ Học, Giờ Thực Tập Và Tự Học - {}
# Vi_phạm - Vô Lễ Với Thầy, Cô Giáo Và Cbvc Nhà Trường - {}
# Vi_phạm - Học Thay Hoặc Nhờ Người Khác Học Thay - {}
# Vi_phạm - Thi, Kiểm Tra Thay, Hoặc Nhờ Thi, Kiểm Tra Thay; Làm Thay, Nhờ Làm Hoặc Sao Chép Tiểu Luận, Đồ Án, Khóa Luận Tốt Nghiệp - {}
# Vi_phạm - Tổ Chức Học Thi, Kiểm Tra Thay; Tổ Chức Làm Thay Tiểu Luận, Đồ Án, Khóa Luận Tốt Nghiệp - {}
# Vi_phạm - Mang Tài Liệu Vào Phòng Thi, Đưa Đề Thi Ra Ngoài Nhờ Làm Thay, Ném Tài Liệu Vào Phòng Thi, Vi Phạm Quy Chế Thi; Thi Không Có Lý Do Chính Đáng Hoặc Hình Thức Gian Lận Khác Trong Học Tập, Thi Cử, Kiểm Tra - {}
# Vi_phạm - Có Hành Vi Chậm Nộp Hoặc Không Nộp Học Phí, Bảo Hiểm Y Tế Theo Quy Định Của Nhà Trường Mà Không Có Lý Do Chính Đáng - {}
# Vi_phạm - Làm Hư Hỏng Tài Sản Trong Ktx Và Các Tài Sản Khác Của Trường - {}
# Vi_phạm - Uống Rượu, Bia Trong Giờ Học - {}
# Vi_phạm - Hút Thuốc Lá Trong Giờ Học, Phòng Học, Phòng Thí Nghiệm Và Nơi Cấm Hút Thuốc Theo Quy Định - {}
# Vi_phạm - Đánh Bạc Dưới Mọi Hình Thức - {}
# Vi_phạm - Tàng Trữ, Lưu Hành, Truy Cập, Sử Dụng Sản Phẩm Văn Hóa Đồi Trụy Hoặc Tham Gia Các Hoạt Động Mê Tín Dị Đoan, Hoạt Động Tôn Giáo Trái Phép - {}
# Vi_phạm - Buôn Bán, Vận Chuyển, Tàng Trữ, Lôi Kéo Người Khác Sử Dụng Ma Túy - {}
# Vi_phạm - Sử Dụng Ma Túy - {}
# Vi_phạm - Chứa Chấp, Môi Giới Mại Dâm - {}
# Vi_phạm - Hoạt Động Mại Dâm - {}
# Vi_phạm - Lấy Cắp Tài Sản, Chứa Chấp, Tiêu Thụ Tài Sản Do Lấy Cắp Mà Có - {}
# Vi_phạm - Chứa Chấp, Buôn Bán Vũ Khí, Chất Nổ Và Hàng Cấm Theo Quy Định Của Nhà Nước - {}
# Vi_phạm - Đưa Phản Vật Vào Trong Trường, Ký Túc Xá Ảnh Hưởng Xấu Đến An Ninh, Trật Tự Trong Nhà Trường - {}
# Vi_phạm - Đánh Nhau, Lôi Kéo Hoặc Tham Gia Tổ Chức Đánh Nhau - {}
# Vi_phạm - Kích Động, Lôi Kéo Người Khác Đánh Nhau Hoặc Gây Rối An Ninh, Trật Tự - {}
# Vi_phạm - Tham Gia Biểu Tình, Tụ Tập Đông Người, Khiếu Kiện Trái Quy Định Của Pháp Luật - {}
# Vi_phạm - Đăng Tải, Bình Luận, Chia Sẻ Bài Viết, Hình Ảnh Có Nội Dung Dung Tục, Bạo Lực, Đồi Trụy, Xâm Phạm An Ninh Quốc Gia, Chống Phá Đảng Và Nhà Nước, Xuyên Tạc, Vu Khống, Xúc Phạm Uy Tín Của Tổ Chức, Danh Dự Và Nhân Phẩm Của Cá Nhân Trên Mạng Internet - {}
# Vi_phạm - Có Hành Động Quấy Rối, Dâm Ô, Xâm Phạm Nhân Phẩm, Đời Tư Của Người Khác - {}
# Vi_phạm - Vi Phạm Các Quy Định Về An Toàn Giao Thông - {}
# Vi_phạm - Các Vi Phạm Khác - {}
# Chủ_thể - Nhà Trường - {}
# Chủ_thể - Cơ Quan Chức Năng - {}
# Khái_niệm - Quy Chế Đào Tạo - {}
# Khái_niệm - Quy Định Của Pháp Luật - {}
#
# (Vi_phạm: Đến Muộn Giờ Học, Giờ Thực Tập; Nghỉ Học Không Phép Hoặc Quá Phép) - (QUY_ĐỊNH:{}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Mất Trật Tự, Làm Việc Riêng Trong Giờ Học, Giờ Thực Tập Và Tự Học) - (QUY_ĐỊNH:{}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Vô Lễ Với Thầy, Cô Giáo Và Cbvc Nhà Trường) - (XỬ_LÝ:{'mứcĐộ': 'khiển trách đến buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Học Thay Hoặc Nhờ Người Khác Học Thay) - (XỬ_LÝ:{'mứcĐộ': 'khiển trách đến buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Thi, Kiểm Tra Thay, Hoặc Nhờ Thi, Kiểm Tra Thay; Làm Thay, Nhờ Làm Hoặc Sao Chép Tiểu Luận, Đồ Án, Khóa Luận Tốt Nghiệp) - (XỬ_LÝ:{'lần1': 'Đình chỉ có thời hạn', 'lần2': 'Buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Tổ Chức Học Thi, Kiểm Tra Thay; Tổ Chức Làm Thay Tiểu Luận, Đồ Án, Khóa Luận Tốt Nghiệp) - (XỬ_LÝ:{'mứcĐộ': 'theo quy định của pháp luật'}) - (Chủ_thể:Cơ Quan Chức Năng)
# (Vi_phạm: Mang Tài Liệu Vào Phòng Thi, Đưa Đề Thi Ra Ngoài Nhờ Làm Thay, Ném Tài Liệu Vào Phòng Thi, Vi Phạm Quy Chế Thi; Thi Không Có Lý Do Chính Đáng Hoặc Hình Thức Gian Lận Khác Trong Học Tập, Thi Cử, Kiểm Tra) - (XỬ_LÝ:{}) - (Khái_niệm:Quy Chế Đào Tạo)
# (Vi_phạm: Có Hành Vi Chậm Nộp Hoặc Không Nộp Học Phí, Bảo Hiểm Y Tế Theo Quy Định Của Nhà Trường Mà Không Có Lý Do Chính Đáng) - (XỬ_LÝ:{'mứcĐộ': 'nhắc nhở, khiển trách đến buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Làm Hư Hỏng Tài Sản Trong Ktx Và Các Tài Sản Khác Của Trường) - (XỬ_LÝ:{'mứcĐộ': 'khiển trách đến buộc thôi học và bồi thường thiệt hại'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Uống Rượu, Bia Trong Giờ Học) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Hút Thuốc Lá Trong Giờ Học, Phòng Học, Phòng Thí Nghiệm Và Nơi Cấm Hút Thuốc Theo Quy Định) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Đánh Bạc Dưới Mọi Hình Thức) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học và giao cho cơ quan chức năng xử lý theo quy định pháp luật'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Tàng Trữ, Lưu Hành, Truy Cập, Sử Dụng Sản Phẩm Văn Hóa Đồi Trụy Hoặc Tham Gia Các Hoạt Động Mê Tín Dị Đoan, Hoạt Động Tôn Giáo Trái Phép) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học và giao cho cơ quan chức năng xử lý theo quy định pháp luật'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Buôn Bán, Vận Chuyển, Tàng Trữ, Lôi Kéo Người Khác Sử Dụng Ma Túy) - (XỬ_LÝ:{'mứcĐộ': 'nghiêm, theo quy định pháp luật'}) - (Chủ_thể:Cơ Quan Chức Năng)
# (Vi_phạm: Sử Dụng Ma Túy) - (XỬ_LÝ:{'mứcĐộ': 'Buộc thôi học và xử lý theo quy định về sinh viên liên quan đến ma túy'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Chứa Chấp, Môi Giới Mại Dâm) - (XỬ_LÝ:{'mứcĐộ': 'Buộc thôi học và theo quy định pháp luật'}) - (Chủ_thể:Cơ Quan Chức Năng)
# (Vi_phạm: Hoạt Động Mại Dâm) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học và xử lý theo quy định pháp luật'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Lấy Cắp Tài Sản, Chứa Chấp, Tiêu Thụ Tài Sản Do Lấy Cắp Mà Có) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học và giao cho cơ quan chức năng xử lý nếu nghiêm trọng'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Chứa Chấp, Buôn Bán Vũ Khí, Chất Nổ Và Hàng Cấm Theo Quy Định Của Nhà Nước) - (XỬ_LÝ:{'mứcĐộ': 'Buộc thôi học và theo quy định pháp luật'}) - (Chủ_thể:Cơ Quan Chức Năng)
# (Vi_phạm: Đưa Phản Vật Vào Trong Trường, Ký Túc Xá Ảnh Hưởng Xấu Đến An Ninh, Trật Tự Trong Nhà Trường) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Đánh Nhau, Lôi Kéo Hoặc Tham Gia Tổ Chức Đánh Nhau) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học và giao cho cơ quan chức năng xử lý nếu nghiêm trọng'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Kích Động, Lôi Kéo Người Khác Đánh Nhau Hoặc Gây Rối An Ninh, Trật Tự) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học và giao cho cơ quan chức năng xử lý nếu nghiêm trọng'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Tham Gia Biểu Tình, Tụ Tập Đông Người, Khiếu Kiện Trái Quy Định Của Pháp Luật) - (XỬ_LÝ:{'lần1': 'Khiển trách', 'lần2': 'Cảnh cáo', 'lần3': 'Đình chỉ có thời hạn', 'lần4': 'Buộc thôi học và theo quy định của pháp luật'}) - (Chủ_thể:Cơ Quan Chức Năng)
# (Vi_phạm: Đăng Tải, Bình Luận, Chia Sẻ Bài Viết, Hình Ảnh Có Nội Dung Dung Tục, Bạo Lực, Đồi Trụy, Xâm Phạm An Ninh Quốc Gia, Chống Phá Đảng Và Nhà Nước, Xuyên Tạc, Vu Khống, Xúc Phạm Uy Tín Của Tổ Chức, Danh Dự Và Nhân Phẩm Của Cá Nhân Trên Mạng Internet) - (XỬ_LÝ:{'mứcĐộ': 'khiển trách đến buộc thôi học, nếu nghiêm trọng giao cho cơ quan chức năng xử lý theo quy định của pháp luật'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Có Hành Động Quấy Rối, Dâm Ô, Xâm Phạm Nhân Phẩm, Đời Tư Của Người Khác) - (XỬ_LÝ:{'mứcĐộ': 'khiển trách đến buộc thôi học, nếu nghiêm trọng giao cho cơ quan chức năng xử lý theo quy định của pháp luật'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Vi Phạm Các Quy Định Về An Toàn Giao Thông) - (XỬ_LÝ:{'mứcĐộ': 'khiển trách đến buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# (Vi_phạm: Các Vi Phạm Khác) - (XỬ_LÝ:{'mứcĐộ': 'nhắc nhở, phê bình, trừ điểm rèn luyện hoặc xử lý kỷ luật từ khiển trách đến buộc thôi học'}) - (Chủ_thể:Nhà Trường)
# ----------------------------------------

# %%
# Hàm để chuyển các thực thể và quan hệ vào neo4j
def insert_nodes_and_relationships(driver, nodes, relationships):
	with driver.session() as session:
		# Chèn nodes
		for node in nodes:
			x = str(node.type).replace(',', '')
			x = x.replace(' ', '_')

			cypher_query = f"""
				MERGE (n:{x} {{id: $id}})
				SET n += $properties
			"""
			session.run(
				cypher_query,
				id=node.id,
				properties=node.properties
			)

		# Chèn relationships
		for relationship in relationships:
			x = str(relationship.source.type).replace(',', '')
			x = x.replace(' ', '_')

			y = str(relationship.target.type).replace(',', '')
			y = y.replace(' ', '_')

			z = str(relationship.type).replace(',', '')
			z = z.replace(' ', '_')

			cypher_query = f"""
				MATCH (a:{x} {{id: $source_id}}), 
							(b:{y} {{id: $target_id}})
				MERGE (a)-[r:{z}]->(b)
				SET r += $properties
			"""	
			session.run(
				cypher_query,
				source_id=relationship.source.id,
				target_id=relationship.target.id,
				properties=relationship.properties
			)

# %%
# Hàm tạo connect đến neo4j
from neo4j import GraphDatabase

def connect_to_neo4j(uri, user, password, db):
	driver = GraphDatabase.driver(uri, auth=(user, password), database=db)
	return driver

# %%
# Kết nối đến Neo4j
uri = "bolt://localhost:7687"
user = "neo4j"
password = "adminadmin"
db = 'quydinh-quyche-full-temperature-0'
driver = connect_to_neo4j(uri, user, password, db)

# %%
for x in graph_documents:
	insert_nodes_and_relationships(driver, x.nodes, x.relationships)

# %%
driver.close()

# %%
# Prompt cho tác vụ tìm kiếm(cũ)
CYPHER_GENERATION_TEMPLATE = """
Task: Sinh truy vấn Cypher để truy xuất dữ liệu từ đồ thị tri thức về quy chế đào tạo đại học.

Instructions:
- Phân tích kỹ câu hỏi và trích xuất các thành phần quan trọng như thực thể (node), quan hệ (edge) và thuộc tính (property).
- Chỉ sử dụng các loại node, quan hệ và thuộc tính có trong schema bên dưới. Không thêm bất kỳ phần tử nào không có trong schema.
- Các nhãn node được đặt bằng tiếng Việt (ví dụ: :Chương_trình, :Chủ_thể, :Học, :Quy_định...).
- Các nhãn quan hệ được đặt bằng tiếng Việt (ví dụ: :ÁP_DỤNG, :HỌC, :QUY_ĐỊNH...).
- Truy vấn phải trả lời chính xác câu hỏi dựa trên cấu trúc đồ thị.
- Chỉ trả về truy vấn Cypher. Không viết giải thích, ghi chú, hoặc định nghĩa gì thêm.

Schema đồ thị:
{schema}

Ví dụ truy vấn:

# Các phương thức đóng học phí bao gồm các phương thức nào?
# Cách 1
MATCH (n:`Hoạt_động`)-[]->(m)
WHERE n.id contains 'Phương Thức Đóng Học Phí'
return n, m
# Cách 2
MATCH (n:`Phương_thức`)-[:`ÁP_DỤNG_CHO`]->(m)
WHERE m.id contains 'Sinh Viên'
return n.id

# Học phần bắt buộc là gì?
MATCH (n: Loại_học_phần)
WHERE n.id contains 'Học Phần Bắt Buộc'
return n.`định_nghĩa`

# Khi nào sinh viên bị buộc thôi học?
MATCH (n: Chủ_thể)-[:`CÓ_HÀNH_VI`]->(m)-[:`BỊ_XỬ_LÝ`]->(x)
WHERE n.id contains 'Sinh Viên' 
AND x.id contains 'Buộc Thôi Học'
return n, m, x

# Thời hạn đóng học phí là khi nào?
MATCH (n:`Chủ_thể`)-[r1:`PHẢI_TUÂN_THỦ`]->(m)-[r2]->(x)
where n.id contains 'Sinh Viên' 
and m.id contains 'Thời Hạn Đóng Học Phí'
RETURN n, r1, m, r2, x 

The question is:
{question}
"""

# %%
# Prompt cho tác vụ tìm kiếm(mới)

CYPHER_GENERATION_TEMPLATE = """
Task: Sinh truy vấn Cypher để truy xuất dữ liệu từ đồ thị tri thức về quy chế đào tạo đại học.

Instructions:
- Phân tích kỹ câu hỏi và xác định các thành phần quan trọng như thực thể (node), quan hệ (edge), và thuộc tính (property).
- Chỉ sử dụng các loại node, quan hệ và thuộc tính có trong schema bên dưới. Không thêm bất kỳ phần tử nào không có trong schema.
- Các nhãn node được đặt bằng tiếng Việt (ví dụ: :Chương_trình, :Chủ_thể, :Học, :Quy_định...).
- Các loại quan hệ cũng được đặt bằng tiếng Việt (ví dụ: :ÁP_DỤNG, :HỌC, :QUY_ĐỊNH...).
- Mọi truy vấn **phải trả về đầy đủ tất cả thuộc tính** của node và relationship bằng `properties(...)`. Nếu cần, sử dụng `type(...)` để lấy tên quan hệ.
- **Chỉ được sử dụng phép so sánh `CONTAINS` trong mệnh đề WHERE. Không được sử dụng phép gán bằng (`=`).**
- Không viết lời giải thích, ghi chú hoặc định nghĩa. Chỉ trả về truy vấn Cypher.

Schema đồ thị:
{schema}

Ví dụ truy vấn:

# Các phương thức đóng học phí bao gồm các phương thức nào?
MATCH (n:`Hoạt_động`)-[r]->(m)
WHERE n.id CONTAINS 'Phương Thức Đóng Học Phí'
RETURN 
  properties(n) AS n_properties, 
  type(r) AS r_type, 
  properties(r) AS r_properties, 
  properties(m) AS m_properties

# Cách các phương thức đóng học phí áp dụng cho sinh viên?
MATCH (n:`Phương_thức`)-[r:`ÁP_DỤNG_CHO`]->(m)
WHERE m.id CONTAINS 'Sinh Viên'
RETURN 
  properties(n) AS n_properties, 
  type(r) AS r_type, 
  properties(r) AS r_properties, 
  properties(m) AS m_properties

# Học phần bắt buộc là gì?
MATCH (n:Loại_học_phần)
WHERE n.id CONTAINS 'Học Phần Bắt Buộc'
RETURN properties(n) AS n_properties

# Khi nào sinh viên bị buộc thôi học?
MATCH (n:`Chủ_thể`)-[r1:`CÓ_HÀNH_VI`]->(m)-[r2:`BỊ_XỬ_LÝ`]->(x)
WHERE n.id CONTAINS 'Sinh Viên' 
  AND x.id CONTAINS 'Buộc Thôi Học'
RETURN 
  properties(n) AS n_properties, 
  type(r1) AS r1_type, 
  properties(r1) AS r1_properties,
  properties(m) AS m_properties, 
  type(r2) AS r2_type, 
  properties(r2) AS r2_properties, 
  properties(x) AS x_properties

# Thời hạn đóng học phí là khi nào?
MATCH (n:`Chủ_thể`)-[r1:`PHẢI_TUÂN_THỦ`]->(m)-[r2]->(x)
WHERE n.id CONTAINS 'Sinh Viên' 
  AND m.id CONTAINS 'Thời Hạn Đóng Học Phí'
RETURN 
  properties(n) AS n_properties, 
  type(r1) AS r1_type, 
  properties(r1) AS r1_properties, 
  properties(m) AS m_properties, 
  type(r2) AS r2_type, 
  properties(r2) AS r2_properties, 
  properties(x) AS x_properties

The question is:
{question}
"""

# %%
from langchain.prompts.prompt import PromptTemplate

CYPHER_GENERATION_PROMPT = PromptTemplate(
	input_variables=["schema", "question"],
	template=CYPHER_GENERATION_TEMPLATE
)

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_neo4j import GraphCypherQAChain, Neo4jGraph
load_dotenv()

graph = Neo4jGraph(url="bolt://localhost:7687", username="neo4j", password="adminadmin", database="prompt-1-temperature-1", enhanced_schema=True)

# print(graph.schema)

os.environ["OPENAI_API_KEY"] = str(os.getenv("OPENAI_API_KEY"))
llm = ChatOpenAI(temperature=1, model="gpt-4o")

chain = GraphCypherQAChain.from_llm(
	llm,
	graph=graph,
	verbose=True,
	top_k=5,
	allow_dangerous_requests=True,
	# validate_cypher=True,
	cypher_prompt=CYPHER_GENERATION_PROMPT,
)

# %%
result = chain.invoke({"query": "Điều kiện nào cần để tham gia khóa luận tốt nghiệp?"})

print(f"Final answer: {result['result']}")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (n:`Khái_niệm`)-[r]->(m)
# WHERE n.id CONTAINS 'Khóa Luận Tốt Nghiệp'
# RETURN
#   properties(n) AS n_properties,
#   type(r) AS r_type,
#   properties(r) AS r_properties,
#   properties(m) AS m_properties
# Full Context:
# []
#
# > Finished chain.
# Final answer: Hiện tại tôi không có thông tin cụ thể về điều kiện tham gia khóa luận tốt nghiệp. Bạn vui lòng liên hệ trực tiếp với phòng đào tạo hoặc khoa chuyên môn của trường để được hướng dẫn chi tiết nhé.

# %%
# Cách hiển thị Final answer dễ quan sát hơn
import textwrap

def prettyCypherChain(question: str) -> str:
	response = chain.run(question)
	print(textwrap.fill(response, 60))

# %%
prettyCypherChain("Đào tạo chính quy là gì?")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (n:Khái_niệm {id: "Đào Tạo Chính Quy"}) RETURN n.định_nghĩa
#
# Full Context:
# [{'n.định_nghĩa': None}]
#
# > Finished chain.
# Tôi không biết câu trả lời cho câu hỏi "Đào tạo chính quy là
# gì?".
